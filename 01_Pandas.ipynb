# %% [markdown]
# <a href="https://colab.research.google.com/github/SzczotkaMichal/FirstRemoteRepo/blob/main/01_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

print(f"Numpy: {np.__version__}")
print(f"Pandas: {pd.__version__}")
# Out:
# Numpy: 1.26.4
# Pandas: 2.2.2

# %%
def fetch_financial_data(company='AMZN'):
    """
    This function fetch stock market quotations.
    """
    import pandas_datareader.data as web
    return web.DataReader(name=company, data_source='stooq')

df = fetch_financial_data()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1256 entries, 2025-02-28 to 2020-03-03
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1256 non-null   float64
#  1   High    1256 non-null   float64
#  2   Low     1256 non-null   float64
#  3   Close   1256 non-null   float64
#  4   Volume  1256 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 58.9 KB

# %%
# Display the first 6 rows of the DataFrame 'df' to preview the data.
df.head(6)
# Out:
#               Open     High     Low   Close    Volume
# Date
# 2025-02-28  209.06  212.620  206.99  212.28  51771737
# 2025-02-27  218.35  219.970  208.37  208.74  40548571
# 2025-02-26  214.94  218.160  213.09  214.35  39120603
# 2025-02-25  211.63  213.340  204.16  212.80  58957977
# 2025-02-24  217.45  217.715  212.42  212.71  42387585
# 2025-02-21  223.28  223.310  214.74  216.58  55323850

# %%
# Display the last 5(default value if not given) rows of DataFrame 'df' to preview the data.
df.tail()
# Out:
#                Open     High      Low    Close     Volume
# Date
# 2020-03-09  88.6930  93.1385  88.0645  90.0305  156264640
# 2020-03-06  93.7500  95.5435  93.4750  95.0545  105471600
# 2020-03-05  96.6500  98.0360  95.5000  96.2015   94964200
# 2020-03-04  97.3285  98.9000  96.1000  98.7915   95458380
# 2020-03-03  98.7685  99.8165  94.4045  95.4495  150689820

# %%
df.dtypes
# Out:
# Open      float64
# High      float64
# Low       float64
# Close     float64
# Volume      int64
# dtype: object

# %%
# .describe(): This is the method applied to the DataFrame df.
# It automatically calculates and displays various summary statistics.
df.describe()
# Out:
#               Open         High          Low        Close        Volume
# count  1256.000000  1256.000000  1256.000000  1256.000000  1.256000e+03
# mean    150.814671   152.646590   148.842274   150.779081  6.682575e+07
# std      33.754501    33.792981    33.580559    33.689143  3.321664e+07
# min      82.075500    83.480000    81.301600    81.820000  1.500750e+07
# 25%     125.007500   126.730000   123.627500   125.267500  4.455420e+07
# 50%     156.300000   158.356000   154.264000   155.836000  5.896385e+07
# 75%     172.586500   174.275750   170.520075   172.241250  7.962140e+07
# max     239.015000   242.520000   238.030000   242.060000  2.726617e+08

# %%
# Check for missing values (NaN) in the DataFrame
missing_values = df.isna().sum()
missing_values
# Out:
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
df['Close'].head(10)
# Out:
# Date
# 2025-02-28    212.28
# 2025-02-27    208.74
# 2025-02-26    214.35
# 2025-02-25    212.80
# 2025-02-24    212.71
# 2025-02-21    216.58
# 2025-02-20    222.88
# 2025-02-19    226.63
# 2025-02-18    226.65
# 2025-02-14    228.68
# Name: Close, dtype: float64

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
df['High'].max()
# Out:
# 242.52

# %%
df['Low'].min()
# Out:
# 81.3016

# %%
#W przypadku indeksu daty operacja slicing wymaga, aby daty były posortowane rosnąco.
df = df.sort_index()  # Sortuje DataFrame według indeksu
df.loc['2021-12-02':'2021-12-10']
# Out:
#                Open     High      Low    Close    Volume
# Date
# 2021-12-02  173.000  174.635  171.188  171.868  64725760
# 2021-12-03  172.750  173.493  166.930  169.490  80711000
# 2021-12-06  169.650  173.695  166.934  171.368  68860000
# 2021-12-07  174.600  177.499  173.334  176.164  66410720
# 2021-12-08  176.151  177.180  174.751  176.158  45253660
# 2021-12-09  175.750  176.969  174.140  174.171  46061820
# 2021-12-10  175.417  175.927  170.500  172.212  60689760

# %%
df.loc['2021-05-10']
# Out:
# Open      1.641160e+02
# High      1.641500e+02
# Low       1.595000e+02
# Close     1.595240e+02
# Volume    1.167721e+08
# Name: 2021-05-10 00:00:00, dtype: float64

# %%
df.index.dtype
# Out:
# dtype('<M8[ns]')

# %%
filtr3000 = df['Close'] > 150
df.loc[filtr3000]
# Out:
#                Open     High      Low    Close     Volume
# Date
# 2020-07-06  146.748  152.994  146.500  152.852  137612840
# 2020-07-07  152.928  153.478  149.500  150.006  105150280
# 2020-07-08  151.130  154.198  150.622  154.056  100752700
# 2020-07-09  155.800  159.694  153.700  159.132  127773180
# 2020-07-10  159.588  160.750  156.785  160.000  109719640
# ...             ...      ...      ...      ...        ...
# 2025-02-24  217.450  217.715  212.420  212.710   42387585
# 2025-02-25  211.630  213.340  204.160  212.800   58957977
# 2025-02-26  214.940  218.160  213.090  214.350   39120603
# 2025-02-27  218.350  219.970  208.370  208.740   40548571
# 2025-02-28  209.060  212.620  206.990  212.280   51771737
#
# [722 rows x 5 columns]

# %%
srednia = df[['High', 'Low']].mean(axis=1)
df['Average'] = srednia
df.head()
# Out:
#                Open     High      Low    Close     Volume   Average
# Date
# 2020-03-03  98.7685  99.8165  94.4045  95.4495  150689820  97.11050
# 2020-03-04  97.3285  98.9000  96.1000  98.7915   95458380  97.50000
# 2020-03-05  96.6500  98.0360  95.5000  96.2015   94964200  96.76800
# 2020-03-06  93.7500  95.5435  93.4750  95.0545  105471600  94.50925
# 2020-03-09  88.6930  93.1385  88.0645  90.0305  156264640  90.60150
